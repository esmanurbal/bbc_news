# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import string

#Tokenization and Lowercasing
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
from sklearn.cluster import KMeans

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ABAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ABAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ABAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ABAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
df = pd.read_csv("./bbc_news.csv")

# %%
df.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                          pubDate  \
# 0  Mon, 07 Mar 2022 08:01:56 GMT
# 1  Sun, 06 Mar 2022 22:49:58 GMT
# 2  Mon, 07 Mar 2022 00:14:42 GMT
# 3  Mon, 07 Mar 2022 00:05:40 GMT
# 4  Mon, 07 Mar 2022 08:15:53 GMT
#
#                                                guid  \
# 0  https://www.bbc.co.uk/news/world-europe-60638042
# 1  https://www.bbc.co.uk/news/world-europe-60641873
# 2      https://www.bbc.co.uk/news/business-60623941
# 3            https://www.bbc.co.uk/news/uk-60579079
# 4      https://www.bbc.co.uk/news/business-60642786
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/world-europe-606380...
# 1  https://www.bbc.co.uk/news/world-europe-606418...
# 2  https://www.bbc.co.uk/news/business-60623941?a...
# 3  https://www.bbc.co.uk/news/uk-60579079?at_medi...
# 4  https://www.bbc.co.uk/news/business-60642786?a...
#
#                                          description
# 0  The Ukrainian president says the country will ...
# 1  Jeremy Bowen was on the frontline in Irpin, as...
# 2  One of the world's biggest fertiliser firms sa...
# 3  The parents of the Manchester Arena bombing's ...
# 4  Consumers are feeling the impact of higher ene...

# %%
df.shape
# Out:
# (26304, 5)

# %%
# Drop one or more columns
df['Concatenated'] = df['title'] + df['description']
columns_to_drop = ['title','description','pubDate', 'guid', 'link']
df = df.drop(columns=columns_to_drop)

# Display the DataFrame after dropping columns
print("\nDataFrame after dropping columns:")
df
# Out:
# DataFrame after dropping columns:
#                                             Concatenated
# 0      Ukraine: Angry Zelensky vows to punish Russian...
# 1      War in Ukraine: Taking cover in a town under a...
# 2      Ukraine war 'catastrophic for global food'One ...
# 3      Manchester Arena bombing: Saffie Roussos's par...
# 4      Ukraine conflict: Oil price soars to highest l...
# ...                                                  ...
# 26299  Hamas hostages: Stories of the people taken fr...
# 26300  Images show major damage to Gaza's oldest mosq...
# 26301  Palestinians mourn writer killed in air strike...
# 26302  Gaza Strip in maps: How life has changed in tw...
# 26303  Video shows stripped Palestinian men detained ...
#
# [26304 rows x 1 columns]

# %%
# Create a new DataFrame for processed data
processed_df = pd.DataFrame()

# Tokenize the text
processed_df['tokenized_text'] = df['Concatenated'].apply(lambda x: word_tokenize(str(x).lower()))

# Remove stopwords
stop_words = set(stopwords.words('english'))
processed_df['filtered_text'] = processed_df['tokenized_text'].apply(lambda x: [word for word in x if word.lower() not in stop_words])

# Lemmatize the text
lemmatizer = WordNetLemmatizer()
processed_df['lemmatized_text'] = processed_df['filtered_text'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# The lemmatized text is converted back to a single string per article and stored in the 'preprocessed_text' column.
processed_df['preprocessed_text'] = processed_df['lemmatized_text'].apply(' '.join)

# Split the lemmatized text into words and remove punctuation
translator = str.maketrans('', '', string.punctuation)
processed_df['all_words'] = processed_df['preprocessed_text'].apply(lambda x: x.translate(translator).split())

# Flatten the list of lists
all_words_flat = [word for sublist in processed_df['all_words'] for word in sublist]

# Count word occurrences
word_counts = Counter(all_words_flat)

# Display the most common words
most_common_words = word_counts.most_common(10)  # Change 10 to the desired number of most common words
print("Most common words:")
for word, count in most_common_words:
    print(f"{word}: {count}")
# Out:
# Most common words:
# s: 12192
# say: 4999
# world: 3169
# cup: 2420
# england: 2306
# ukraine: 2077
# uk: 1949
# new: 1936
# woman: 1706
# year: 1666

# %%
processed_df
# Out:
#                                           tokenized_text  \
# 0      [ukraine, :, angry, zelensky, vows, to, punish...
# 1      [war, in, ukraine, :, taking, cover, in, a, to...
# 2      [ukraine, war, 'catastrophic, for, global, foo...
# 3      [manchester, arena, bombing, :, saffie, rousso...
# 4      [ukraine, conflict, :, oil, price, soars, to, ...
# ...                                                  ...
# 26299  [hamas, hostages, :, stories, of, the, people,...
# 26300  [images, show, major, damage, to, gaza, 's, ol...
# 26301  [palestinians, mourn, writer, killed, in, air,...
# 26302  [gaza, strip, in, maps, :, how, life, has, cha...
# 26303  [video, shows, stripped, palestinian, men, det...
#
#                                            filtered_text  \
# 0      [ukraine, :, angry, zelensky, vows, punish, ru...
# 1      [war, ukraine, :, taking, cover, town, attackj...
# 2      [ukraine, war, 'catastrophic, global, food'one...
# 3      [manchester, arena, bombing, :, saffie, rousso...
# 4      [ukraine, conflict, :, oil, price, soars, high...
# ...                                                  ...
# 26299  [hamas, hostages, :, stories, people, taken, i...
# 26300  [images, show, major, damage, gaza, 's, oldest...
# 26301  [palestinians, mourn, writer, killed, air, str...
# 26302  [gaza, strip, maps, :, life, changed, two, mon...
# 26303  [video, shows, stripped, palestinian, men, det...
#
#                                          lemmatized_text  \
# 0      [ukraine, :, angry, zelensky, vow, punish, rus...
# 1      [war, ukraine, :, taking, cover, town, attackj...
# 2      [ukraine, war, 'catastrophic, global, food'one...
# 3      [manchester, arena, bombing, :, saffie, rousso...
# 4      [ukraine, conflict, :, oil, price, soar, highe...
# ...                                                  ...
# 26299  [hamas, hostage, :, story, people, taken, isra...
# 26300  [image, show, major, damage, gaza, 's, oldest,...
# 26301  [palestinian, mourn, writer, killed, air, stri...
# 26302  [gaza, strip, map, :, life, changed, two, mont...
# 26303  [video, show, stripped, palestinian, men, deta...
#
#                                        preprocessed_text  \
# 0      ukraine : angry zelensky vow punish russian at...
# 1      war ukraine : taking cover town attackjeremy b...
# 2      ukraine war 'catastrophic global food'one worl...
# 3      manchester arena bombing : saffie roussos 's p...
# 4      ukraine conflict : oil price soar highest leve...
# ...                                                  ...
# 26299  hamas hostage : story people taken israelit th...
# 26300  image show major damage gaza 's oldest mosqueh...
# 26301  palestinian mourn writer killed air strikewrit...
# 26302  gaza strip map : life changed two monthsfind m...
# 26303  video show stripped palestinian men detained g...
#
#                                                all_words
# 0      [ukraine, angry, zelensky, vow, punish, russia...
# 1      [war, ukraine, taking, cover, town, attackjere...
# 2      [ukraine, war, catastrophic, global, foodone, ...
# 3      [manchester, arena, bombing, saffie, roussos, ...
# 4      [ukraine, conflict, oil, price, soar, highest,...
# ...                                                  ...
# 26299  [hamas, hostage, story, people, taken, israeli...
# 26300  [image, show, major, damage, gaza, s, oldest, ...
# 26301  [palestinian, mourn, writer, killed, air, stri...
# 26302  [gaza, strip, map, life, changed, two, monthsf...
# 26303  [video, show, stripped, palestinian, men, deta...
#
# [26304 rows x 5 columns]

# %%
processed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26304 entries, 0 to 26303
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tokenized_text     26304 non-null  object
#  1   filtered_text      26304 non-null  object
#  2   lemmatized_text    26304 non-null  object
#  3   preprocessed_text  26304 non-null  object
#  4   all_words          26304 non-null  object
# dtypes: object(5)
# memory usage: 1.0+ MB

# %%
sample_size = 1000 
random_sample = processed_df.sample(n=sample_size)
random_sample
# Out:
#                                           tokenized_text  \
# 1443   [canada, proposes, foreign, buyers, home, real...
# 22934  [man, creates, rock, sculpture, in, cornwall, ...
# 138    [war, in, ukraine, :, five, times, russians, h...
# 18480  [the, ashes, 2023, :, australia, hit, england,...
# 13315  [apple, sales, in, biggest, fall, since, 2019t...
# ...                                                  ...
# 2954   [gcse, and, a-level, exam, invigilator, shorta...
# 1750   [', i, 'm, shocked, by, my, church, leaders, i...
# 19368  [newspaper, review, :, 'heatwave, from, hell, ...
# 12628  [greyfriars, bobby, film, star, dog, 's, remai...
# 1541   [ukraine, :, johnson, pledges, aid, to, zelens...
#
#                                            filtered_text  \
# 1443   [canada, proposes, foreign, buyers, home, real...
# 22934  [man, creates, rock, sculpture, cornwall, wife...
# 138    [war, ukraine, :, five, times, russians, stood...
# 18480  [ashes, 2023, :, australia, hit, england, edgb...
# 13315  [apple, sales, biggest, fall, since, 2019the, ...
# ...                                                  ...
# 2954   [gcse, a-level, exam, invigilator, shortages, ...
# 1750   [', 'm, shocked, church, leaders, moscow, ', -...
# 19368  [newspaper, review, :, 'heatwave, hell, ', far...
# 12628  [greyfriars, bobby, film, star, dog, 's, remai...
# 1541   [ukraine, :, johnson, pledges, aid, zelensky, ...
#
#                                          lemmatized_text  \
# 1443   [canada, proposes, foreign, buyer, home, real,...
# 22934  [man, creates, rock, sculpture, cornwall, wife...
# 138    [war, ukraine, :, five, time, russian, stood, ...
# 18480  [ash, 2023, :, australia, hit, england, edgbas...
# 13315  [apple, sale, biggest, fall, since, 2019the, d...
# ...                                                  ...
# 2954   [gcse, a-level, exam, invigilator, shortage, m...
# 1750   [', 'm, shocked, church, leader, moscow, ', -,...
# 19368  [newspaper, review, :, 'heatwave, hell, ', far...
# 12628  [greyfriars, bobby, film, star, dog, 's, remai...
# 1541   [ukraine, :, johnson, pledge, aid, zelensky, k...
#
#                                        preprocessed_text  \
# 1443   canada proposes foreign buyer home real estate...
# 22934  man creates rock sculpture cornwall wife shops...
# 138    war ukraine : five time russian stood ukrainev...
# 18480  ash 2023 : australia hit england edgbaston sho...
# 13315  apple sale biggest fall since 2019the decline ...
# ...                                                  ...
# 2954   gcse a-level exam invigilator shortage mean pa...
# 1750   ' 'm shocked church leader moscow ' - priest u...
# 19368  newspaper review : 'heatwave hell ' farage 's ...
# 12628  greyfriars bobby film star dog 's remains foun...
# 1541   ukraine : johnson pledge aid zelensky kyiv mee...
#
#                                                all_words
# 1443   [canada, proposes, foreign, buyer, home, real,...
# 22934  [man, creates, rock, sculpture, cornwall, wife...
# 138    [war, ukraine, five, time, russian, stood, ukr...
# 18480  [ash, 2023, australia, hit, england, edgbaston...
# 13315  [apple, sale, biggest, fall, since, 2019the, d...
# ...                                                  ...
# 2954   [gcse, alevel, exam, invigilator, shortage, me...
# 1750   [m, shocked, church, leader, moscow, priest, u...
# 19368  [newspaper, review, heatwave, hell, farage, s,...
# 12628  [greyfriars, bobby, film, star, dog, s, remain...
# 1541   [ukraine, johnson, pledge, aid, zelensky, kyiv...
#
# [1000 rows x 5 columns]

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(random_sample['preprocessed_text'])
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
sns.heatmap(cosine_similarities)
# Out:
# <Axes: >

# %%
# Apply K-Means clustering
num_clusters = 3  # Change this to the desired number of clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(cosine_similarities)
# Out:
# C:\Users\ABAR\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3, random_state=42)

# %%
from sklearn.manifold import TSNE

# Dimensionality reduction using t-SNE
tsne = TSNE(n_components=2, random_state=42)
tsne_representation = tsne.fit_transform(cosine_similarities)

# Add the cluster labels to the DataFrame
random_sample['cluster'] = kmeans.labels_

# Display the resultig DataFrame with cluster labels
random_sample
# Out:
#                                           tokenized_text  \
# 1443   [canada, proposes, foreign, buyers, home, real...
# 22934  [man, creates, rock, sculpture, in, cornwall, ...
# 138    [war, in, ukraine, :, five, times, russians, h...
# 18480  [the, ashes, 2023, :, australia, hit, england,...
# 13315  [apple, sales, in, biggest, fall, since, 2019t...
# ...                                                  ...
# 2954   [gcse, and, a-level, exam, invigilator, shorta...
# 1750   [', i, 'm, shocked, by, my, church, leaders, i...
# 19368  [newspaper, review, :, 'heatwave, from, hell, ...
# 12628  [greyfriars, bobby, film, star, dog, 's, remai...
# 1541   [ukraine, :, johnson, pledges, aid, to, zelens...
#
#                                            filtered_text  \
# 1443   [canada, proposes, foreign, buyers, home, real...
# 22934  [man, creates, rock, sculpture, cornwall, wife...
# 138    [war, ukraine, :, five, times, russians, stood...
# 18480  [ashes, 2023, :, australia, hit, england, edgb...
# 13315  [apple, sales, biggest, fall, since, 2019the, ...
# ...                                                  ...
# 2954   [gcse, a-level, exam, invigilator, shortages, ...
# 1750   [', 'm, shocked, church, leaders, moscow, ', -...
# 19368  [newspaper, review, :, 'heatwave, hell, ', far...
# 12628  [greyfriars, bobby, film, star, dog, 's, remai...
# 1541   [ukraine, :, johnson, pledges, aid, zelensky, ...
#
#                                          lemmatized_text  \
# 1443   [canada, proposes, foreign, buyer, home, real,...
# 22934  [man, creates, rock, sculpture, cornwall, wife...
# 138    [war, ukraine, :, five, time, russian, stood, ...
# 18480  [ash, 2023, :, australia, hit, england, edgbas...
# 13315  [apple, sale, biggest, fall, since, 2019the, d...
# ...                                                  ...
# 2954   [gcse, a-level, exam, invigilator, shortage, m...
# 1750   [', 'm, shocked, church, leader, moscow, ', -,...
# 19368  [newspaper, review, :, 'heatwave, hell, ', far...
# 12628  [greyfriars, bobby, film, star, dog, 's, remai...
# 1541   [ukraine, :, johnson, pledge, aid, zelensky, k...
#
#                                        preprocessed_text  \
# 1443   canada proposes foreign buyer home real estate...
# 22934  man creates rock sculpture cornwall wife shops...
# 138    war ukraine : five time russian stood ukrainev...
# 18480  ash 2023 : australia hit england edgbaston sho...
# 13315  apple sale biggest fall since 2019the decline ...
# ...                                                  ...
# 2954   gcse a-level exam invigilator shortage mean pa...
# 1750   ' 'm shocked church leader moscow ' - priest u...
# 19368  newspaper review : 'heatwave hell ' farage 's ...
# 12628  greyfriars bobby film star dog 's remains foun...
# 1541   ukraine : johnson pledge aid zelensky kyiv mee...
#
#                                                all_words  cluster
# 1443   [canada, proposes, foreign, buyer, home, real,...        1
# 22934  [man, creates, rock, sculpture, cornwall, wife...        1
# 138    [war, ukraine, five, time, russian, stood, ukr...        0
# 18480  [ash, 2023, australia, hit, england, edgbaston...        1
# 13315  [apple, sale, biggest, fall, since, 2019the, d...        1
# ...                                                  ...      ...
# 2954   [gcse, alevel, exam, invigilator, shortage, me...        1
# 1750   [m, shocked, church, leader, moscow, priest, u...        0
# 19368  [newspaper, review, heatwave, hell, farage, s,...        1
# 12628  [greyfriars, bobby, film, star, dog, s, remain...        1
# 1541   [ukraine, johnson, pledge, aid, zelensky, kyiv...        0
#
# [1000 rows x 6 columns]

# %%
# Visualize the clusters with a scatter plot
sns.scatterplot(x=tsne_representation[:, 0], y=tsne_representation[:, 1], hue=random_sample['cluster'], palette='viridis')
plt.title('t-SNE Visualization of Clusters')
plt.show()

# %%
from wordcloud import WordCloud

# Create a WordCloud for each cluster
for cluster_label in range(num_clusters):
    # Extract text for the current cluster
    cluster_text = ' '.join(random_sample[random_sample['cluster'] == cluster_label]['preprocessed_text'])

    # Generate WordCloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cluster_text)

    # Plot the WordCloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for Cluster {cluster_label}')
    plt.axis('off')
    plt.show()
